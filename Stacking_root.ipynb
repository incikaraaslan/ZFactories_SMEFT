# %%
import uproot
import awkward as ak
import hist
import mplhep
import matplotlib.pyplot as plt
import numpy as np
from mt2 import mt2
from scipy.optimize import minimize
# from scipy import optimize
from scipy.optimize import brute
from scipy.optimize import differential_evolution
import matplotlib.pyplot as plt

import uproot
import awkward as ak
import numpy as np
import glob

# %%
# Configuration
input_pattern = "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/*.root"  # Adjust path/pattern as needed
tree_name = "Delphes"           # Replace with your actual TTree name
output_file = "combined.root"
# Gather files
file_list = glob.glob(input_pattern)
if not file_list:
    raise FileNotFoundError("No ROOT files found matching the pattern.")
# Initialize list to store data
branches_data = {}
# Loop over files and extract tree data
for i, file in enumerate(file_list):
    with uproot.open(file) as f:
        tree = f[tree_name]
        # arrays = tree.arrays()
        branch_names = ["MissingET.Eta", "MissingET.Phi" ,"MissingET.MET", "Muon.PT", "Muon.Eta", "Muon.Phi", "Muon.Charge", "Electron.PT", "Electron.Eta", "Electron.Phi", "Electron.Charge","KTjet.PT", "KTjet.Eta",
"KTjet.Phi" , "KTjet.Phi", "KTjet.Charge", "KTjet.Mass"]  # Replace with your actual branch names
        arrays = tree.arrays(branch_names)
        # arrays = tree.arrays(tree.keys())
        # print(tree.keys())

        if i == 0:
            # Initialize with first file's data
            branches_data = {k: arrays[k] for k in branch_names}
        else:
            # Concatenate across files
            for k in branch_names:
                branches_data[k] = ak.concatenate([branches_data[k], arrays[k]])
                
#         if i == 0:
#             # Initialize branch storage
#             for key in arrays:
#                 branches_data[key] = arrays[key]
#         else:
#             # Concatenate arrays
#             for key in arrays:
#                 branches_data[key] = ak.concatenate([branches_data[key], arrays[key]])
# # Write to a new ROOT file
# with uproot.recreate(output_file) as f:
#     f[tree_name] = branches_data
# print(f"Combined {len(file_list)} files into {output_file}")

# %%
test_tree = uproot.open("/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-16.root")["Delphes"]

# %%
import os

input_files = ["/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-16.root",
               "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-15.root",
              "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-14.root",
              "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-13.root",
              "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-12.root",
              "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-11.root",
              "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-10.root",
              "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-09.root",
              "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-08.root",
              "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-07.root",
              "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-06.root",
              "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-05.root",
              "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-04.root",
              "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-03.root",
              "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-02.root",
              "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-01.root"]

output_file = "combined.root"

os.system(f"hadd {output_file} " + " ".join(input_files))
# Out:
# 0
# hadd Target file: combined.root
# hadd compression setting for all output: 101
# hadd Source file 1: /Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-16.root
# hadd Source file 2: /Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-15.root
# hadd Source file 3: /Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-14.root
# hadd Source file 4: /Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-13.root
# hadd Source file 5: /Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-12.root
# hadd Source file 6: /Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-11.root
# hadd Source file 7: /Users/hengameh/Downloads/MG5_aMC_v3_5_3/Root_anni/ww-annihilation-tajj-events/recon_events-10.root
# ...

# %%
import os

input_files = ["/Users/hengameh/Downloads/MG5_aMC_v3_5_3/ww-vbf-charged-root-files/recon_events-01.root",
               "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/ww-vbf-charged-root-files/recon_events-02.root",
              "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/ww-vbf-charged-root-files/recon_events-03.root",
              "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/ww-vbf-charged-root-files/recon_events-04.root",
              "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/ww-vbf-charged-root-files/recon_events-05.root"]

output_file = "combinedVBF.root"

os.system(f"hadd {output_file} " + " ".join(input_files))
# Out:
# hadd Target file: combinedVBF.root
# hadd compression setting for all output: 101
# hadd Source file 1: /Users/hengameh/Downloads/MG5_aMC_v3_5_3/ww-vbf-charged-root-files/recon_events-01.root
# Warning in <TClass::Init>: no dictionary for class HepMCEvent is available
# Warning in <TClass::Init>: no dictionary for class Event is available
# Warning in <TClass::Init>: no dictionary for class Weight is available
# Warning in <TClass::Init>: no dictionary for class GenParticle is available
# Warning in <TClass::Init>: no dictionary for class SortableObject is available
# Warning in <TClass::Init>: no dictionary for class Jet is available
# Warning in <TClass::Init>: no dictionary for class MissingET is available
# Warning in <TClass::Init>: no dictionary for class Photon is available
# Warning in <TClass::Init>: no dictionary for class Electron is available
# Warning in <TClass::Init>: no dictionary for class Muon is available
# ...

# %%
import os

input_files = ["/Users/hengameh/Downloads/MG5_aMC_v3_5_3/VBF_neut_root/unweighted_events1_neutVBF.root",
               "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/VBF_neut_root/unweighted_events2_neutVBF.root",
               "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/VBF_neut_root/unweighted_events3_neutVBF.root",
               "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/VBF_neut_root/unweighted_events4_neutVBF.root",
               "/Users/hengameh/Downloads/MG5_aMC_v3_5_3/VBF_neut_root/unweighted_events5_neutVBF.root"]

output_file = "combinedVBF_neut.root"

os.system(f"hadd {output_file} " + " ".join(input_files))
# Out:
# hadd Target file: combinedVBF_neut.root
# hadd compression setting for all output: 101
# hadd Source file 1: /Users/hengameh/Downloads/MG5_aMC_v3_5_3/VBF_neut_root/unweighted_events1_neutVBF.root
# hadd Source file 2: /Users/hengameh/Downloads/MG5_aMC_v3_5_3/VBF_neut_root/unweighted_events2_neutVBF.root
# hadd Source file 3: /Users/hengameh/Downloads/MG5_aMC_v3_5_3/VBF_neut_root/unweighted_events3_neutVBF.root
# hadd Source file 4: /Users/hengameh/Downloads/MG5_aMC_v3_5_3/VBF_neut_root/unweighted_events4_neutVBF.root
# hadd Source file 5: /Users/hengameh/Downloads/MG5_aMC_v3_5_3/VBF_neut_root/unweighted_events5_neutVBF.root
# hadd Target path: combinedVBF_neut.root:/
# Warning in <TClass::Init>: no dictionary for class HepMCEvent is available
# Warning in <TClass::Init>: no dictionary for class Event is available
# Warning in <TClass::Init>: no dictionary for class Weight is available
# Warning in <TClass::Init>: no dictionary for class GenParticle is available
# ...

# %%
def get_met(tree):
    return ak.zip({"met": tree["MissingET.MET"].array(), "eta": tree["MissingET.Eta"].array(), \
                  "phi": tree["MissingET.Phi"].array(),})
def get_met(branches_data):
    return ak.zip({"met": branches_data["MissingET.MET"], "eta": branches_data["MissingET.Eta"], \
                  "phi": branches_data["MissingET.Phi"],})

def get_muons2(tree):
    return ak.zip({"pt": tree["Muon.PT"], "eta": tree["Muon.Eta"], \
                  "phi": tree["Muon.Phi"], "charge":tree["Muon.Charge"],})

def get_electrons2(tree):
    return ak.zip({"pt": tree["Electron.PT"], "eta": tree["Electron.Eta"], \
                  "phi": tree["Electron.Phi"], "charge":tree["Electron.Charge"],})

#def get_jets(tree):
#    return ak.zip({"pt": tree["Jet.PT"].array(), "eta": tree["Jet.Eta"].array(), \
#                  "phi": tree["Jet.Phi"].array(), "charge":tree["Jet.Charge"].array(),})

def get_jets2(tree):
    return ak.zip({"pt": tree["KTjet.PT"], "eta": tree["KTjet.Eta"], \
                  "phi": tree["KTjet.Phi"], "charge":tree["KTjet.Charge"],
                  "mass": tree["KTjet.Mass"],})

# %%
def extract_data2(data_tree, lepton_isolation_val = 0.4):
    #Extract data and filter to have one muon and one isolated tau jet
    (data_muons,data_electrons,data_jets,data_met) = get_particles(data_tree)
    two_jet_condit=ak.num(data_jets,axis=1)==2
    
    muons_eta = data_muons["eta"][two_jet_condit]
    muons_phi = data_muons["phi"][two_jet_condit]
    muons_pt = data_muons["pt"][two_jet_condit]
    jets_eta = data_jets["eta"][two_jet_condit]
    jets_phi = data_jets["phi"][two_jet_condit]
    jets_pt = data_jets["pt"][two_jet_condit]
    jets_mass = data_jets["mass"][two_jet_condit]
    met = data_met["met"][two_jet_condit]
    met_eta = data_met["eta"][two_jet_condit]
    met_phi = data_met["phi"][two_jet_condit]
    num = len(data_tree["Particle"].array())

    # Compute observables
    #Fix with axis label
    diff_eta =  abs(compute_min_alignment(met_eta, jets_eta))
    #Fix with axis label
    diff_R = compute_delta_R(met_eta, met_phi, jets_eta, jets_phi)
    Eval = compute_E(jets_eta, jets_pt, jets_mass)
    mt2_val = mt2(jets_mass[:,0], jets_pt[:,0] *np.cos(jets_phi[:,0]), jets_pt[:,0] *np.sin(jets_phi[:,0]),  # Visible 1: mass, px, py
    jets_mass[:,1], jets_pt[:,1]*np.cos(jets_phi[:,1]), jets_pt[:,1]*np.sin(jets_phi[:,1]),  # Visible 2: mass, px, py
    met*np.cos(met_phi), met*np.sin(met_phi),  # Missing transverse momentum: x, y
    0, 0)  # Invisible 1 mass, invisible 2 mass
    
    # Print total # of events and # of one muon events
    print(num, ",", ak.sum(two_jet_condit))
    
    return (muons_eta, muons_phi, muons_pt, jets_eta, jets_phi, jets_pt, jets_mass,\
           met_eta, met_phi, met, num, diff_eta, diff_R, Eval, mt2_val
           )

# %%
get_met(branches_data)
# Out:
# <Array [[{met: 1.58e+03, eta: ..., ...}], ...] type='32115 * var * {met: fl...'>
